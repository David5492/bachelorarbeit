# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import ElasticNet
from validation_metric import total_validation

from datetime import datetime

start = datetime.now()

#load data
df = pd.read_csv("C:/Users/test/Documents/GitHub/bachelorarbeit/_climate_change_mitigation/data/processed/berlin_preprocessed.csv")

# fill NaN:
df = df.fillna(df.mean())

# split data
X = df.iloc[:,1:]
y = df.iloc[:,0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# def ElasticNetReg():
def enReg(X_train, X_test, y_train, y_test):
    # creating and training
    en = ElasticNet(random_state=42)
    en.fit(X_train,y_train)

    # predicting values:
    return en.predict(X_test)

y_pred = enReg(X_train, X_test, y_train, y_test)
print(metric)

stop = datetime.now()
print(str(stop - start)) #just4fun
# Out:
#                value
# MAE             0.13
# MAPE (%)         inf
# MSE             0.03
# RMSE (Units)    0.17
# r-squared (%)   1.82
# 0:00:01.022264

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

_ = sns.scatterplot(y_test,y_pred)
plt.show()

# %%
_ = plt.hist(y_test)
plt.show()

# %%
_ = plt.hist(y_pred, bins=50)
plt.show()

# %%
y_pred
# Out:
# array([0.34746278, 0.32025198, 0.31365647, ..., 0.35464533, 0.3217023 ,
#        0.313691  ])

# %%
y_test
# Out:
# 12678    0.356927
# 14245    0.102287
# 4169     0.197669
# 15669    0.210186
# 357      0.188606
#            ...
# 16331    0.072076
# 13458    0.234786
# 4786     0.196159
# 1399     0.270609
# 15688    0.115969
# Name: energy_consumption, Length: 5074, dtype: float64
